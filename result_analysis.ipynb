# %% [markdown]
# # Memorization Metrics Analysis
#
# This notebook analyzes memorization behaviors across different models, datasets, and normalization types. It leverages previously computed results (e.g., memorization_metrics.csv, features.csv) to explore:
# - Correlation between mobility features and memorization (e.g., how radius of gyration or diversity relate to exposure).
# - Comparative strength of different memorization types (e.g., substitute vs. shuffle).
# - Cross-model comparison to assess which models are more prone to memorization.
#
# The goal is to identify patterns, biases, or vulnerabilities in user memorization by location prediction models.

# %%
# %pip install joypy
# Out:
# Collecting joypy
#   Downloading joypy-0.2.6-py2.py3-none-any.whl.metadata (812 bytes)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/site-packages (from joypy) (2.3.3)
# Requirement already satisfied: scipy>=0.11.0 in /usr/local/lib/python3.12/site-packages (from joypy) (1.16.2)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.12/site-packages (from joypy) (2.2.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/site-packages (from joypy) (3.10.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/site-packages (from pandas>=0.20.0->joypy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/site-packages (from pandas>=0.20.0->joypy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/site-packages (from pandas>=0.20.0->joypy) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/site-packages (from matplotlib->joypy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/site-packages (from matplotlib->joypy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/site-packages (from matplotlib->joypy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/site-packages (from matplotlib->joypy) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/site-packages (from matplotlib->joypy) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/site-packages (from matplotlib->joypy) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/site-packages (from matplotlib->joypy) (3.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->joypy) (1.17.0)
# Downloading joypy-0.2.6-py2.py3-none-any.whl (8.6 kB)
# Installing collected packages: joypy
# Successfully installed joypy-0.2.6
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import json
from scipy.stats import binned_statistic_2d
from scipy.ndimage import gaussian_filter
from collections import defaultdict
import numpy as np
from scipy.stats import gaussian_kde

# %%
DATASETS = {
    "ShenzhenUrban": {
        "type1": "/home/akouamdj/mobleak-datasets/PreprocessedData/2SplittedData/ShenzhenUrban/NormalizationType1/",
        "type2_home": "/home/akouamdj/mobleak-datasets/PreprocessedData/2SplittedData/ShenzhenUrban/NormalizationType2/Home/",
        "type2_work": "/home/akouamdj/mobleak-datasets/PreprocessedData/2SplittedData/ShenzhenUrban/NormalizationType2/Work/",
        "type3": "/home/akouamdj/mobleak-datasets/PreprocessedData/2SplittedData/ShenzhenUrban/NormalizationType3/",
    },
    "ShanghaiKaggle": {
        "type1": "/home/akouamdj/mobleak-datasets/PreprocessedData/2SplittedData/ShanghaiKaggle/NormalizationType1/",
        "type2_home": "/home/akouamdj/mobleak-datasets/PreprocessedData/2SplittedData/ShanghaiKaggle/NormalizationType2/Home/",
        "type2_work": "/home/akouamdj/mobleak-datasets/PreprocessedData/2SplittedData/ShanghaiKaggle/NormalizationType2/Work/",
        "type3": "/home/akouamdj/mobleak-datasets/PreprocessedData/2SplittedData/ShanghaiKaggle/NormalizationType3/",
    }
}

dataset_name = "ShanghaiKaggle"

# %% [markdown]
# #### Question 1: Is there any memorization?

# %%
model_name = "deepmove_simple"
type_name = "type1"

# Paths
ROOT = Path("results") / dataset_name / model_name / type_name
INPUT_FILE = ROOT / "memorization_metrics.csv"
PERPLEXITY_DIR = ROOT / "perplexity"
OUTPUT_DIR = Path("analysis_outputs") / dataset_name / "question1_memorization" / model_name / type_name
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Load data
df = pd.read_csv(INPUT_FILE)

# Compute log2(N) exposure threshold dynamically from perplexity files
# logN_list = []
# for cluster_file in df["cluster_id"]:
#     perplexity_file = PERPLEXITY_DIR / cluster_file
#     if perplexity_file.exists():
#         try:
#             ref_df = pd.read_csv(perplexity_file)
#             N = len(ref_df)
#             logN_list.append(np.log2(N))
#         except Exception:
#             logN_list.append(np.nan)
#     else:
#         logN_list.append(np.nan)
# df["log2_N"] = logN_list
# df["exposure_gt_logN"] = df["exposure"] > df["log2_N"]

# Summary statistics
summary = {
    "num_trajectories": len(df),
    "gap_mean": df["gap"].mean(),
    "gap_median": df["gap"].median(),
    "percent_gap_below_zero": (df["gap"] < 0).mean() * 100,
    "exposure_mean": df["exposure"].mean(),
    "exposure_median": df["exposure"].median(),
    #"percent_exposure_above_logN": df["exposure_gt_logN"].mean() * 100,
    #"exposure_logN_threshold_mean": np.nanmean(df["log2_N"]),
    "percentile_mean": df["percentile"].mean(),
    "percent_percentile_below_0.1": (df["percentile"] < 0.1).mean() * 100
}

# Save summary
with open(OUTPUT_DIR / "memorization_summary.json", "w") as f:
    json.dump(summary, f, indent=4)

# --- Plotting ---
sns.set_style('whitegrid')
palette = sns.color_palette("deep")
ci = 95

# Exposure CDF
plt.figure(figsize=(4, 4))
#plot_ecdf_with_ci(df["exposure"], "Exposure", OUTPUT_DIR / "exposure_cdf.png")
sns.ecdfplot(df["exposure"], linewidth=2, label="Exposure", color=palette[0])
#avg_logN = np.nanmean(df["log2_N"])
#plt.axvline(avg_logN, color='red', linestyle='--', label=f"mean log₂(N) ≈ {avg_logN:.2f}")
plt.xlabel("Exposure", fontsize=14)
plt.ylabel("CDF", fontsize=14)
plt.legend()
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "exposure_cdf.png", dpi=300)
plt.close()

# Gap CDF
plt.figure(figsize=(4, 4))
sns.ecdfplot(df["gap"], linewidth=2, label="Gap", color=palette[1])
plt.axvline(0, color='red', linestyle='--', label="Gap = 0")
plt.xlabel("Gap", fontsize=14)
plt.ylabel("CDF", fontsize=14)
plt.legend()
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "gap_cdf.png", dpi=300)
plt.close()

# Percentile CDF
plt.figure(figsize=(4, 4))
sns.ecdfplot(df["percentile"], linewidth=2, label="Percentile", color=palette[2])
plt.axvline(0.1, color='red', linestyle='--', label="10% Percentile")
plt.xlabel("Percentile", fontsize=14)
plt.ylabel("CDF", fontsize=14)
plt.legend()
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "percentile_cdf.png", dpi=300)
plt.close()

print(summary)



# Learning curve plot
res_file = Path("results") / dataset_name / model_name / type_name / "model" / "res.txt"

# Try to read and parse the file
if res_file.exists():
    with open(res_file, "r") as f:
        res_data = json.load(f)

    metrics = res_data.get("metrics", {})
    train_loss = metrics.get("train_loss", [])
    valid_loss = metrics.get("valid_loss", [])
    accuracy = metrics.get("accuracy", [])

    epochs = list(range(1, len(train_loss) + 1))

    # Find best epoch by accuracy
    best_acc_epoch = int(np.argmax(accuracy)) + 1
    best_acc = accuracy[best_acc_epoch - 1]

    # Find epoch with minimum validation loss
    best_loss_epoch = int(np.argmin(valid_loss)) + 1
    best_loss = valid_loss[best_loss_epoch - 1]

    # Create the figure and twin axes
    fig, ax1 = plt.subplots(figsize=(5, 3.5))

    # Plot train and validation loss
    ax1.plot(epochs, train_loss, label="Train Loss", marker="o", alpha=0.6)
    ax1.plot(epochs, valid_loss, label="Validation Loss", marker="o", alpha=0.6)
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.tick_params(axis='y')

    # Mark best accuracy epoch
    #ax1.axvline(best_acc_epoch, color="red", linestyle="--", alpha=0.6)
    ax1.axvline(x=best_acc_epoch, color="red", linestyle="--", alpha=0.6, label=f"Best Acc (Epoch {best_acc_epoch})")

    # ax1.text(best_acc_epoch + 0.5, ax1.get_ylim()[1]*0.95,
    #          f"Best Acc (Epoch {best_acc_epoch})",
    #          color="red", fontsize=8)

    # Mark best validation loss epoch
    ax1.scatter([best_loss_epoch], [best_loss], color="green", s=40, label="Min Val Loss")
    # ax1.text(best_loss_epoch + 0.5, best_loss + 0.02,
    #          f"Min Val Loss (Epoch {best_loss_epoch})",
    #          color="green", fontsize=8)

    # Accuracy as secondary Y-axis
    ax2 = ax1.twinx()
    ax2.plot(epochs, accuracy, color="gray", linestyle="--", marker="x", alpha=0.5, label="Validation Accuracy")
    ax2.set_ylabel("Accuracy", color="gray")
    ax2.tick_params(axis='y', labelcolor="gray")

    # Combined legend
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    plt.legend(lines1 + lines2, labels1 + labels2, loc="center", fontsize=8)

    #plt.title(f"Learning Curve – {model_name} on {type_name}")
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "learning_curve.png", dpi=300)
    plt.close()
else:
    print("res.txt not found.")
# Out:
# {'num_trajectories': 2000, 'gap_mean': np.float64(-1.0581904371491038), 'gap_median': np.float64(-1.162645), 'percent_gap_below_zero': np.float64(87.1), 'exposure_mean': np.float64(2.1439974578860097), 'exposure_median': np.float64(1.7858751946471525), 'percentile_mean': np.float64(0.3354867385139166), 'percent_percentile_below_0.1': np.float64(21.8)}

# %%
best_acc_epoch
# Out:
# 11

# %% [markdown]
# #### Question 2: How do individual mobility behaviors correlate with memorization?
# Assess how mobility features (e.g., rg, diversity) correlate with memorization (exposure, gap, etc.)

# %%
model_name = "deepmove_simple"
type_name = "type1"

# Paths
MEMO_PATH = Path("results") / dataset_name / model_name / type_name / "memorization_metrics.csv"
MOBILITY_PATH = Path(DATASETS[dataset_name][type_name]) / "mobility_characteristics.csv"
OUTPUT_DIR = Path("analysis_outputs") / dataset_name / "question2_mobility_correlation" / model_name / type_name
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Load data
df_memo = pd.read_csv(MEMO_PATH)
df_mob = pd.read_csv(MOBILITY_PATH)

# Merge on tid
df = pd.merge(df_memo, df_mob, on="tid")

# Set seaborn style
sns.set_style("whitegrid")
palette = sns.color_palette("deep")
plt.rcParams["figure.figsize"] = (4, 3)

# === 1. CDFs of mobility features ===
mobility_metrics = ['diversity', 'rg_unique', 'stationarity', 'repetitiveness']

for i, metric in enumerate(mobility_metrics):
    plt.figure(figsize=(3, 3))
    sns.ecdfplot(df[metric], linewidth=2, color=palette[i])
    plt.xlabel(metric.replace('_', ' ').title(), fontsize=12)
    plt.ylabel("CDF", fontsize=12)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / f"{metric}_cdf.png", dpi=300)
    plt.close()

# Histogram of profiles
plt.figure(figsize=(3, 3))
sns.countplot(data=df, x="profile", palette="Set2")
plt.xlabel("Mobility Profile", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "profile_histogram.png", dpi=300)
plt.close()

# === 2. Heatmap: Percentile by rg and diversity quartiles ===
try:
    df["rg_q"] = pd.qcut(df["rg_unique"], 5, labels=[f"Q{i+1}" for i in range(5)])
    df["diversity_q"] = pd.qcut(df["diversity"], 5, labels=[f"Q{i+1}" for i in range(5)])

    heatmap_data = df.groupby(["diversity_q", "rg_q"])["percentile"].mean().unstack()

    plt.figure(figsize=(4, 3))
    sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="YlGnBu", 
                cbar_kws={"label": "Avg Memorization Percentile"})
    plt.xlabel("Radius of gyration Quartile (Q1 = Low)", fontsize=12)
    plt.ylabel("Diversity Quartile (Q1 = Low)", fontsize=12)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "heatmap_percentile_by_rg_diversity.png", dpi=300)
    plt.close()

except Exception as e:
    print("Heatmap plot failed:", e)


# === 3. Contour plot: Repetitiveness vs Stationarity ===
try:
    x = df["stationarity"]
    y = df["repetitiveness"]
    z = df["percentile"]

    # Define grid
    xi = np.linspace(x.min(), x.max(), 100)
    yi = np.linspace(y.min(), y.max(), 100)
    xi, yi = np.meshgrid(xi, yi)

    # Interpolate z values on the grid
    from scipy.interpolate import griddata
    zi = griddata((x, y), z, (xi, yi), method='linear')

    # Plot contour
    plt.figure(figsize=(4, 3))
    cp = plt.contourf(xi, yi, zi, levels=20, cmap="RdYlBu")
    plt.colorbar(cp, label="Avg Memorization Percentile")
    plt.xlabel("Stationarity")
    plt.ylabel("Repetitiveness")
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "contour_percentile_by_stationarity_repetitiveness.png", dpi=300)
    plt.close()
except Exception as e:
    print("Contour plot failed:", e)

# === 4. Ridge Plot: Percentile distribution by mobility profile ===
try:
    import joypy

    plt.figure(figsize=(3, 3))
    fig, axes = joypy.joyplot(
        df, 
        by="profile", 
        column="percentile", 
        kind="kde", 
        fill=True, 
        colormap=plt.cm.Blues,
        linewidth=1,
        fade=True,
        alpha=0.9,
        figsize=(3,3)
    )
    plt.xlabel("Memorization Percentile")
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "ridge_percentile_by_profile.png", dpi=300)
    plt.close()
except Exception as e:
    print("Ridge plot failed:", e)

    
# CDF by profile
plt.figure(figsize=(3, 3))
for profile in df["profile"].unique():
    sns.ecdfplot(df[df["profile"] == profile]["percentile"], label=profile, linewidth=2)
plt.xlabel("Memorization Percentile", fontsize=12)
plt.ylabel("CDF", fontsize=12)
plt.legend(title="Profile")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "percentile_by_profile.png", dpi=300)
plt.close()
# Out:
# /tmp/ipykernel_1526416/3712378792.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="profile", palette="Set2")
# /tmp/ipykernel_1526416/3712378792.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   heatmap_data = df.groupby(["diversity_q", "rg_q"])["percentile"].mean().unstack()

# %% [markdown]
# #### Question 3: Are models more prone to certain memorization types?

# %%
# === Config ===
model_name = "deepmove_simple"
#model_name = "markov"
type_names = ["type1", "type2_home", "type2_work", "type3"]
metrics = ["exposure", "gap", "percentile"]

INPUT_ROOT = Path("results") / dataset_name / model_name
OUTPUT_DIR = Path("analysis_outputs") / dataset_name / "question3_memorization_types" / model_name
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# --- Load and tag data for all memorization types ---
df_all = []
for type_name in type_names:
    path = INPUT_ROOT / type_name / "memorization_metrics.csv"
    if path.exists():
        df = pd.read_csv(path)
        df["type"] = type_name
        df_all.append(df)
df_all = pd.concat(df_all, ignore_index=True)

# === 1. CDF plots (Kernel Estimation) for each memorization metric by type ===
for metric in metrics:
    plt.figure(figsize=(3, 3))
    for mem_type in df_all["type"].unique():
        data = df_all[df_all["type"] == mem_type][metric].dropna()
        if len(data) < 2:
            continue  # Skip if not enough data

        # Kernel Density Estimation
        kde = gaussian_kde(data)
        x_vals = np.linspace(data.min(), data.max(), 500)
        pdf = kde(x_vals)
        cdf = np.cumsum(pdf)
        cdf = cdf / cdf[-1]  # Normalize

        plt.plot(x_vals, cdf, label=mem_type, linewidth=2)

    plt.xlabel(metric.title(), fontsize=12)
    plt.ylabel("CDF", fontsize=12)
    plt.legend(fontsize=7)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / f"cdf_{metric}_by_type.png", dpi=300)
    plt.close()

# === 2. Stacked bar chart of mobility profiles per memorization type ===
profile_counts_by_type = defaultdict(lambda: defaultdict(int))
for type_name in type_names:
    mobility_file = Path(DATASETS[dataset_name][type_name]) / "mobility_characteristics.csv"
    # Load and join
    df_mob = pd.read_csv(mobility_file)[["tid", "profile"]]
    counts = df_mob["profile"].value_counts()
    for profile, count in counts.items():
        profile_counts_by_type[type_name][profile] += count
df_counts = pd.DataFrame(profile_counts_by_type).fillna(0).T
df_props = df_counts.div(df_counts.sum(axis=1), axis=0)
plt.figure(figsize=(3, 3))
ax = df_props[["routiner", "regular", "scouter"]].plot(
    kind="bar", stacked=True, colormap="Set3", width=0.7
)
plt.ylabel("", fontsize=12)
plt.xlabel("", fontsize=12)
plt.xticks(rotation=15, fontsize=8)  # Slight rotation for clarity
plt.legend(
    loc="lower center", 
    bbox_to_anchor=(0.5, 1.0),
    ncol=3,
    fontsize=8,
    frameon=False
)
# Annotate percentages
for i, row in enumerate(df_props[["routiner", "regular", "scouter"]].values):
    cum_height = 0
    for j, val in enumerate(row):
        if val > 0.01:  # only annotate if it's not too small
            ax.text(
                i, cum_height + val / 2,
                f"{val*100:.1f}%",
                ha='center', va='center', fontsize=7, color="black"
            )
        cum_height += val

plt.tight_layout()
plt.savefig(OUTPUT_DIR / "stacked_profiles_by_type.png", dpi=300)
plt.close()


# === 3. Boxplots for gap, exposure, percentile by memorization type ===
modes = {
    "": "all",
    "_substitute": "substitute",
    "_stationary": "stationary",
    "_shuffle": "shuffle"
}
df_type3 = df_all[df_all["type"] == "type3"]
for metric in metrics:
    data = []
    for suffix, label in modes.items():
        column = f"{metric}{suffix}"
        if column in df_type3.columns:
            for value in df_type3[column].dropna():
                data.append({"mode": label, metric: value})

    df_metric = pd.DataFrame(data)
    plt.figure(figsize=(4, 3))
    sns.boxplot(data=df_metric, x="mode", y=metric, palette="deep")
    plt.xlabel("", fontsize=12)
    plt.xticks(fontsize=9)
    plt.ylabel(metric.title(), fontsize=12)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / f"boxplot_type3_{metric}_by_mode.png", dpi=300)
    plt.close()

# === 4. Radar Plot: average value of metrics per memorization type ===

# Compute average metrics per type
avg_metrics = df_all.groupby("type")[metrics].median()
avg_metrics["gap"] = avg_metrics["gap"].abs()  # Use absolute gap for radar plot

# Radar plot setup
labels = metrics
num_vars = len(labels)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # repeat first angle

fig, ax = plt.subplots(figsize=(4, 4), subplot_kw=dict(polar=True))
for i, (type_name, row) in enumerate(avg_metrics.iterrows()):
    values = row.tolist()
    values += values[:1]  # repeat first value to close the circle
    ax.plot(angles, values, label=type_name, linewidth=2)
    ax.fill(angles, values, alpha=0.2)

ax.set_thetagrids(np.degrees(angles[:-1]), labels)
#plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1))
plt.legend(fontsize=7)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "radar_median_metrics_by_type.png", dpi=300)
plt.close()


# === 5. Type 3 memorization per hour of the day ===
INPUT_FILE = Path("results") / dataset_name / model_name / "type3" / "memorization_metrics_per_window.csv"
df_win = pd.read_csv(INPUT_FILE)
df_win["hour_bin"] = df_win["hour_of_day"] % 24
df_win["hour_bin"] = pd.cut(
    df_win["hour_bin"],
    bins=[0, 4, 8, 12, 16, 20, 24],
    right=False,
    labels=["[0–3]", "[4–7]", "[8–11]", "[12–15]", "[16–19]", "[20–23]"]
)
for metric in metrics:
    plt.figure(figsize=(4, 3))
    sns.violinplot(
        data=df_win,
        x="hour_bin",
        y=metric,
        inner="quartile",
        scale="width",
        cut=0,
        linewidth=0.8,
        palette="viridis"
    )
    plt.xlabel("Hour of day", fontsize=12)
    plt.ylabel(metric.title(), fontsize=12)
    #plt.title(f"Distribution of {metric.title()} by Hour of Day Period", fontsize=13)
    plt.xticks(rotation=0, fontsize=8)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / f"violin_{metric}_by_hour_period.png", dpi=300)
    plt.close()
# Out:
# /tmp/ipykernel_1526416/963178238.py:105: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_metric, x="mode", y=metric, palette="deep")
# /tmp/ipykernel_1526416/963178238.py:105: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_metric, x="mode", y=metric, palette="deep")
# /tmp/ipykernel_1526416/963178238.py:105: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_metric, x="mode", y=metric, palette="deep")
# /tmp/ipykernel_1526416/963178238.py:152: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/ipykernel_1526416/963178238.py:152: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1526416/963178238.py:152: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/ipykernel_1526416/963178238.py:152: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1526416/963178238.py:152: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/ipykernel_1526416/963178238.py:152: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(

# %% [markdown]
# #### Question 4: Are some models more prone to memorization than others?

# %%
question = "question4_model_comparison"
type_name = "type1"
metrics = ["exposure", "gap", "percentile"]

# Directory where all results are saved
RESULTS_DIR = Path("results") / dataset_name
OUTPUT_DIR = Path("analysis_outputs") / dataset_name / question
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# === Load and merge all models for the selected type ===
dfs = []
model_names = []
carlini_values = {}

for model_dir in RESULTS_DIR.iterdir():
    model_name = model_dir.name
    model_names.append(model_name)

    mem_file = model_dir / type_name / "memorization_metrics.csv"
    carlini_file = model_dir / "canaries" / "carlini_exposure.json"

    if mem_file.exists():
        df = pd.read_csv(mem_file)
        df["model"] = model_name
        df["type"] = type_name
        dfs.append(df)

        # Load Carlini exposure value
        if carlini_file.exists():
            with open(carlini_file, "r") as f:
                data = json.load(f)
                carlini_values[model_name] = {
                    "exposure": data["exposure"],
                    "gap": data["gap"],
                    "percentile": data["percentile"]
                }

df_all = pd.concat(dfs, ignore_index=True)

# === Ridge Plots ===
sns.set_style("whitegrid")
for metric in metrics:
    # Sort models by average metric value (optional, for better order)
    model_order = df_all.groupby("model")[metric].mean().sort_values().index.tolist()
    n_models = len(model_order)
    height_per_facet = 0.7
    total_height = n_models * height_per_facet

    g = sns.FacetGrid(
        df_all, 
        row="model", 
        hue="model", 
        aspect=4, 
        height=height_per_facet, 
        row_order=model_order,
        sharex=True, 
        sharey=False,
        palette="deep"
    )
    g.map(sns.kdeplot, metric, fill=True, alpha=0.6, linewidth=1.5)
    g.set_titles(row_template="{row_name}", size=6)
    g.set_xlabels(metric.title(), fontsize=12)
    g.set_ylabels("")
    g.set(yticks=[])  # Remove density ticks
    g.despine(left=True)

    plt.subplots_adjust(top=0.95, hspace=0.3)
    g.savefig(OUTPUT_DIR / f"ridgeplot_{metric}_by_model.png", dpi=300)
    plt.close()
# sns.set_style("whitegrid")
# n_models = len(model_names)
# n_cols = 3
# n_rows = int(np.ceil(n_models / n_cols))
# for metric in metrics:
#     g = sns.FacetGrid(
#         df_all, 
#         col="model", 
#         col_wrap=n_cols,
#         aspect=1.5, 
#         height=2,
#         sharex=True, 
#         sharey=False,
#         palette="deep"
#     )
#     g.map(sns.kdeplot, metric, fill=True, alpha=0.6, linewidth=1.5)

#     g.set_titles(col_template="{col_name}", size=11)
#     g.set_xlabels(metric.title(), fontsize=12)
#     g.set_ylabels("")
#     g.set(yticks=[])
#     g.despine(left=True)

#     plt.subplots_adjust(top=0.92, hspace=0.4, wspace=0.3)
#     g.savefig(OUTPUT_DIR / f"ridgeplot_{metric}_by_model_grid.png", dpi=300)
#     plt.close()

# === Ridge Plots with Carlini Lines ===
sns.set_style("whitegrid")
for metric in metrics:
    model_order = df_all.groupby("model")[metric].mean().sort_values().index.tolist()
    n_models = len(model_order)
    height_per_facet = 0.7
    total_height = n_models * height_per_facet

    g = sns.FacetGrid(
        df_all,
        row="model",
        hue="model",
        aspect=4,
        height=height_per_facet,
        row_order=model_order,
        sharex=True,
        sharey=False,
        palette="deep"
    )

    g.map(sns.kdeplot, metric, fill=True, alpha=0.6, linewidth=1.5)

    # Add Carlini line per subplot
    for ax, model in zip(g.axes.flat, model_order):
        if model in carlini_values:
            x_val = carlini_values[model][metric]
            ax.axvline(x=x_val, color="black", linestyle="--", linewidth=1)
            ax.text(
                x_val, ax.get_ylim()[1] * 0.8,  # Position text near the top
                "Carlini", rotation=90, color="black", fontsize=5,
                ha="right", va="center"
            )

    g.set_titles(row_template="{row_name}", size=6)
    g.set_xlabels(metric.title(), fontsize=12)
    g.set_ylabels("")
    g.set(yticks=[])
    g.despine(left=True)

    plt.subplots_adjust(top=0.95, hspace=0.3)
    g.savefig(OUTPUT_DIR / f"ridgeplot_{metric}_by_model_with_carlini.png", dpi=300)
    plt.close()

# %% [markdown]
# #### Question 5: Assessing the Impact of Memorization on Cluster-Level Generalization

# %%
# Define model and paths
model_name = "deepmove_simple"  # Change this manually for different models
#model_name = "lstpm"  
type_name = "type1"

BASE_PATH = Path("results") / dataset_name / model_name / type_name
MEM_FILE = BASE_PATH / "memorization_metrics.csv"
TEST_PATH = BASE_PATH / "test"

OUTPUT_DIR = Path("analysis_outputs") / dataset_name / "question5_accuracy_vs_memorization" / model_name
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Load memorization file
df_mem = pd.read_csv(MEM_FILE)
df_mem["cluster_id"] = df_mem["cluster_id"].astype(str)

# Initialize
accuracy_metrics = ["top-1", "top-5", "top-10"]
cluster_accuracy = {}

# Extract accuracy per cluster from test files
for cid in df_mem["cluster_id"].unique():
    cid_clean = cid.replace(".csv", "")
    test_file = TEST_PATH / f"{cid_clean}_topk.csv"
    if not test_file.exists():
        print(f"Test file for cluster {cid} not found, skipping.")
        continue
    df_test = pd.read_csv(test_file)
    cluster_accuracy[cid] = df_test[accuracy_metrics].mean().to_dict()

# Convert accuracy dict to DataFrame
df_acc = pd.DataFrame(cluster_accuracy).T
df_acc.index.name = "cluster_id"
df_acc.reset_index(inplace=True)

# Merge with memorization metrics
df_merged = df_mem.merge(df_acc, on="cluster_id", how="inner")

# Plot 1: Scatterplot with trendline per memorization metric vs top-1 accuracy
mem_metrics = ["exposure", "gap", "percentile"]
for metric in mem_metrics:
    plt.figure(figsize=(3, 3))
    sns.regplot(data=df_merged, x=metric, y="top-1", scatter_kws={"s": 10, "alpha": 0.5}, line_kws={"color": "red"})
    plt.xlabel(metric.title())
    plt.ylabel("Top-1 Accuracy")
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / f"scatter_{metric}_vs_top1.png", dpi=300)
    plt.close()

# Plot 2: Boxplots of memorization metrics grouped by accuracy levels (binned top-k)
quartiles = 5
for metric in mem_metrics:
    df_temp = df_merged.copy()
    # Bin the memorization metric into quartiles (Q1–Q4)
    df_temp[f"{metric}_quartile"] = pd.qcut(df_temp[metric], quartiles, labels=[f"Q{i+1}" for i in range(quartiles)])
    # Melt accuracy columns to long format
    df_long = df_temp.melt(
        id_vars=["tid", "cluster_id", f"{metric}_quartile"],
        value_vars=accuracy_metrics,
        var_name="topk",
        value_name="accuracy"
    )
    # Plot
    plt.figure(figsize=(3, 3))
    sns.boxplot(
        data=df_long,
        x=f"{metric}_quartile",
        y="accuracy",
        hue="topk",
        palette="pastel"
    )
    #plt.xlabel(f"{metric.title()} Quartile", fontsize=12)
    plt.xlabel(f"{metric.title()} Quartile (Q1 = Low)", fontsize=10)
    plt.ylabel("Top-k Accuracy", fontsize=12)
    plt.legend(
        loc="upper center", 
        bbox_to_anchor=(0.5, 1.1), 
        ncol=len(accuracy_metrics),
        fontsize=7,
        title_fontsize=10,
        frameon=False
    )
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / f"boxplot_accuracy_vs_{metric}_quartile.png", dpi=300)
    plt.close()
# Out:
# Test file for cluster cluster_2589456_2589552.csv not found, skipping.
# Test file for cluster cluster_1452528_1452624.csv not found, skipping.
# Test file for cluster cluster_1733712_1733808.csv not found, skipping.
# Test file for cluster cluster_2527248_2527344.csv not found, skipping.
# Test file for cluster cluster_3716304_3716400.csv not found, skipping.
# Test file for cluster cluster_2536944_2537040.csv not found, skipping.
# Test file for cluster cluster_1925472_1925568.csv not found, skipping.
# Test file for cluster cluster_89136_89232.csv not found, skipping.
# Test file for cluster cluster_21696_21792.csv not found, skipping.
# Test file for cluster cluster_732480_732576.csv not found, skipping.
# Test file for cluster cluster_483168_483264.csv not found, skipping.
# Test file for cluster cluster_2627808_2627904.csv not found, skipping.
# Test file for cluster cluster_482736_482832.csv not found, skipping.
# Test file for cluster cluster_3417072_3417168.csv not found, skipping.
# Test file for cluster cluster_3086544_3086640.csv not found, skipping.
# Test file for cluster cluster_1355184_1355280.csv not found, skipping.
# Test file for cluster cluster_17232_17328.csv not found, skipping.
# Test file for cluster cluster_3618144_3618240.csv not found, skipping.
# Test file for cluster cluster_1462224_1462320.csv not found, skipping.
# Test file for cluster cluster_2064528_2064624.csv not found, skipping.
# Test file for cluster cluster_477552_477648.csv not found, skipping.
# Test file for cluster cluster_1828896_1828992.csv not found, skipping.
# Test file for cluster cluster_2057664_2057760.csv not found, skipping.
# Test file for cluster cluster_1076160_1076256.csv not found, skipping.
# Test file for cluster cluster_2204928_2205024.csv not found, skipping.
# Test file for cluster cluster_3362832_3362928.csv not found, skipping.
# Test file for cluster cluster_1175232_1175328.csv not found, skipping.
# Test file for cluster cluster_648384_648480.csv not found, skipping.
# Test file for cluster cluster_2785104_2785200.csv not found, skipping.
# Test file for cluster cluster_343296_343392.csv not found, skipping.
# Test file for cluster cluster_1624608_1624704.csv not found, skipping.
# Test file for cluster cluster_1251168_1251264.csv not found, skipping.
# Test file for cluster cluster_1791504_1791600.csv not found, skipping.
# Test file for cluster cluster_3538848_3538944.csv not found, skipping.
# Test file for cluster cluster_2482032_2482128.csv not found, skipping.
# Test file for cluster cluster_3719232_3719328.csv not found, skipping.
# Test file for cluster cluster_82320_82416.csv not found, skipping.
# Test file for cluster cluster_3405744_3405840.csv not found, skipping.
# Test file for cluster cluster_436800_436896.csv not found, skipping.
# Test file for cluster cluster_3676608_3676704.csv not found, skipping.
# Test file for cluster cluster_623568_623664.csv not found, skipping.
# Test file for cluster cluster_824736_824832.csv not found, skipping.
# Test file for cluster cluster_336816_336912.csv not found, skipping.
# Test file for cluster cluster_552816_552912.csv not found, skipping.
# Test file for cluster cluster_2137776_2137872.csv not found, skipping.
# Test file for cluster cluster_1891488_1891584.csv not found, skipping.
# Test file for cluster cluster_2057952_2058048.csv not found, skipping.
# Test file for cluster cluster_629808_629904.csv not found, skipping.
# Test file for cluster cluster_1916832_1916928.csv not found, skipping.
# Test file for cluster cluster_1369632_1369728.csv not found, skipping.
# Test file for cluster cluster_3252480_3252576.csv not found, skipping.
# Test file for cluster cluster_3176400_3176496.csv not found, skipping.
# Test file for cluster cluster_1868496_1868592.csv not found, skipping.
# Test file for cluster cluster_2181408_2181504.csv not found, skipping.
# Test file for cluster cluster_1103904_1104000.csv not found, skipping.
# Test file for cluster cluster_1139184_1139280.csv not found, skipping.
# Test file for cluster cluster_1293840_1293936.csv not found, skipping.
# Test file for cluster cluster_2375520_2375616.csv not found, skipping.
# Test file for cluster cluster_1044384_1044480.csv not found, skipping.
# Test file for cluster cluster_311184_311280.csv not found, skipping.
# Test file for cluster cluster_1466880_1466976.csv not found, skipping.
# Test file for cluster cluster_2404176_2404272.csv not found, skipping.
# Test file for cluster cluster_1711728_1711824.csv not found, skipping.
# Test file for cluster cluster_3602160_3602256.csv not found, skipping.
# Test file for cluster cluster_404784_404880.csv not found, skipping.
# Test file for cluster cluster_507168_507264.csv not found, skipping.
# Test file for cluster cluster_2344896_2344992.csv not found, skipping.
# Test file for cluster cluster_1402752_1402848.csv not found, skipping.
# Test file for cluster cluster_2458752_2458848.csv not found, skipping.
# Test file for cluster cluster_1479792_1479888.csv not found, skipping.
# Test file for cluster cluster_1830000_1830096.csv not found, skipping.
# Test file for cluster cluster_127344_127440.csv not found, skipping.
# Test file for cluster cluster_1216896_1216992.csv not found, skipping.
# Test file for cluster cluster_2716896_2716992.csv not found, skipping.
# Test file for cluster cluster_3099360_3099456.csv not found, skipping.
# Test file for cluster cluster_354096_354192.csv not found, skipping.
# Test file for cluster cluster_2477136_2477232.csv not found, skipping.
# Test file for cluster cluster_3671328_3671424.csv not found, skipping.
# Test file for cluster cluster_846864_846960.csv not found, skipping.
# Test file for cluster cluster_3365520_3365616.csv not found, skipping.
# Test file for cluster cluster_127200_127296.csv not found, skipping.
# Test file for cluster cluster_516000_516096.csv not found, skipping.
# Test file for cluster cluster_2763072_2763168.csv not found, skipping.
# Test file for cluster cluster_208416_208512.csv not found, skipping.
# Test file for cluster cluster_207984_208080.csv not found, skipping.
# Test file for cluster cluster_2753856_2753952.csv not found, skipping.
# Test file for cluster cluster_1302624_1302720.csv not found, skipping.
# Test file for cluster cluster_686976_687072.csv not found, skipping.
# Test file for cluster cluster_3697632_3697728.csv not found, skipping.
# Test file for cluster cluster_3772848_3772944.csv not found, skipping.
# Test file for cluster cluster_985920_986016.csv not found, skipping.
# Test file for cluster cluster_1634880_1634976.csv not found, skipping.
# Test file for cluster cluster_1271712_1271808.csv not found, skipping.
# Test file for cluster cluster_1550688_1550784.csv not found, skipping.
# Test file for cluster cluster_1621104_1621200.csv not found, skipping.
# Test file for cluster cluster_626112_626208.csv not found, skipping.
# Test file for cluster cluster_272640_272736.csv not found, skipping.
# Test file for cluster cluster_3353808_3353904.csv not found, skipping.
# Test file for cluster cluster_127488_127584.csv not found, skipping.
# Test file for cluster cluster_693984_694080.csv not found, skipping.
# Test file for cluster cluster_3109680_3109776.csv not found, skipping.
# Test file for cluster cluster_2074944_2075040.csv not found, skipping.
# Test file for cluster cluster_2416560_2416656.csv not found, skipping.
# Test file for cluster cluster_1764144_1764240.csv not found, skipping.
# Test file for cluster cluster_3579648_3579744.csv not found, skipping.
# Test file for cluster cluster_3174912_3175008.csv not found, skipping.
# Test file for cluster cluster_1976688_1976784.csv not found, skipping.
# Test file for cluster cluster_3156432_3156528.csv not found, skipping.
# Test file for cluster cluster_3638304_3638400.csv not found, skipping.
# Test file for cluster cluster_1070976_1071072.csv not found, skipping.
# Test file for cluster cluster_2812608_2812704.csv not found, skipping.
# Test file for cluster cluster_2417760_2417856.csv not found, skipping.
# Test file for cluster cluster_47136_47232.csv not found, skipping.
# Test file for cluster cluster_2032128_2032224.csv not found, skipping.
# Test file for cluster cluster_2354304_2354400.csv not found, skipping.
# Test file for cluster cluster_1980960_1981056.csv not found, skipping.
# Test file for cluster cluster_2190960_2191056.csv not found, skipping.
# Test file for cluster cluster_2095152_2095248.csv not found, skipping.
# Test file for cluster cluster_1851408_1851504.csv not found, skipping.
# Test file for cluster cluster_3042912_3043008.csv not found, skipping.
# Test file for cluster cluster_3016896_3016992.csv not found, skipping.
# Test file for cluster cluster_2352144_2352240.csv not found, skipping.
# Test file for cluster cluster_1585536_1585632.csv not found, skipping.
# Test file for cluster cluster_2477424_2477520.csv not found, skipping.
# Test file for cluster cluster_2994384_2994480.csv not found, skipping.
# Test file for cluster cluster_3095184_3095280.csv not found, skipping.
# Test file for cluster cluster_1691472_1691568.csv not found, skipping.
# Test file for cluster cluster_1104432_1104528.csv not found, skipping.
# Test file for cluster cluster_797568_797664.csv not found, skipping.
# Test file for cluster cluster_824448_824544.csv not found, skipping.
# Test file for cluster cluster_1526736_1526832.csv not found, skipping.
# Test file for cluster cluster_824880_824976.csv not found, skipping.
# Test file for cluster cluster_3381792_3381888.csv not found, skipping.
# Test file for cluster cluster_3031392_3031488.csv not found, skipping.
# Test file for cluster cluster_2960400_2960496.csv not found, skipping.
# Test file for cluster cluster_273312_273408.csv not found, skipping.
# Test file for cluster cluster_1276128_1276224.csv not found, skipping.
# Test file for cluster cluster_2135616_2135712.csv not found, skipping.
# Test file for cluster cluster_1498128_1498224.csv not found, skipping.
# Test file for cluster cluster_19536_19632.csv not found, skipping.
# Test file for cluster cluster_874560_874656.csv not found, skipping.
# Test file for cluster cluster_3467904_3468000.csv not found, skipping.
# Test file for cluster cluster_2042352_2042448.csv not found, skipping.
# Test file for cluster cluster_2841696_2841792.csv not found, skipping.
# Test file for cluster cluster_96336_96432.csv not found, skipping.
# Test file for cluster cluster_3417216_3417312.csv not found, skipping.
# Test file for cluster cluster_3654480_3654576.csv not found, skipping.
# Test file for cluster cluster_1008000_1008096.csv not found, skipping.
# Test file for cluster cluster_2029824_2029920.csv not found, skipping.
# Test file for cluster cluster_3308208_3308304.csv not found, skipping.
# Test file for cluster cluster_1555776_1555872.csv not found, skipping.
# Test file for cluster cluster_1362480_1362576.csv not found, skipping.
# Test file for cluster cluster_3503376_3503472.csv not found, skipping.
# Test file for cluster cluster_1046400_1046496.csv not found, skipping.
# Test file for cluster cluster_3096672_3096768.csv not found, skipping.
# Test file for cluster cluster_3676320_3676416.csv not found, skipping.
# Test file for cluster cluster_3389712_3389808.csv not found, skipping.
# Test file for cluster cluster_240048_240144.csv not found, skipping.
# Test file for cluster cluster_1776432_1776528.csv not found, skipping.
# Test file for cluster cluster_2107344_2107440.csv not found, skipping.
# Test file for cluster cluster_477840_477936.csv not found, skipping.
# Test file for cluster cluster_1395888_1395984.csv not found, skipping.
# Test file for cluster cluster_2263728_2263824.csv not found, skipping.
# Test file for cluster cluster_3122880_3122976.csv not found, skipping.
# Test file for cluster cluster_1673856_1673952.csv not found, skipping.
# Test file for cluster cluster_1874832_1874928.csv not found, skipping.
# Test file for cluster cluster_3645264_3645360.csv not found, skipping.
# Test file for cluster cluster_2838192_2838288.csv not found, skipping.
# Test file for cluster cluster_2458512_2458608.csv not found, skipping.
# Test file for cluster cluster_1190496_1190592.csv not found, skipping.
# Test file for cluster cluster_3070368_3070464.csv not found, skipping.
# Test file for cluster cluster_2054064_2054160.csv not found, skipping.
# Test file for cluster cluster_3488928_3489024.csv not found, skipping.
# Test file for cluster cluster_3633600_3633696.csv not found, skipping.
# Test file for cluster cluster_157632_157728.csv not found, skipping.
# Test file for cluster cluster_2960688_2960784.csv not found, skipping.
# Test file for cluster cluster_778992_779088.csv not found, skipping.
# Test file for cluster cluster_3602544_3602640.csv not found, skipping.
# Test file for cluster cluster_1913328_1913424.csv not found, skipping.
# Test file for cluster cluster_1295232_1295328.csv not found, skipping.
# Test file for cluster cluster_2485392_2485488.csv not found, skipping.
# Test file for cluster cluster_736368_736464.csv not found, skipping.
# Test file for cluster cluster_238416_238512.csv not found, skipping.
# Test file for cluster cluster_3281328_3281424.csv not found, skipping.
# Test file for cluster cluster_3376416_3376512.csv not found, skipping.
# Test file for cluster cluster_1527024_1527120.csv not found, skipping.
# Test file for cluster cluster_2095296_2095392.csv not found, skipping.
# Test file for cluster cluster_1868640_1868736.csv not found, skipping.
# Test file for cluster cluster_144816_144912.csv not found, skipping.
# Test file for cluster cluster_3522624_3522720.csv not found, skipping.
# Test file for cluster cluster_3158976_3159072.csv not found, skipping.
# Test file for cluster cluster_2057424_2057520.csv not found, skipping.
# Test file for cluster cluster_2176128_2176224.csv not found, skipping.
# Test file for cluster cluster_2918208_2918304.csv not found, skipping.
# Test file for cluster cluster_368064_368160.csv not found, skipping.
# Test file for cluster cluster_482880_482976.csv not found, skipping.
# Test file for cluster cluster_2064816_2064912.csv not found, skipping.
# Test file for cluster cluster_2156640_2156736.csv not found, skipping.
# Test file for cluster cluster_2769504_2769600.csv not found, skipping.
# Test file for cluster cluster_3377616_3377712.csv not found, skipping.
# Test file for cluster cluster_1323600_1323696.csv not found, skipping.
# Test file for cluster cluster_279408_279504.csv not found, skipping.
# Test file for cluster cluster_2055264_2055360.csv not found, skipping.
# Test file for cluster cluster_2423424_2423520.csv not found, skipping.
# Test file for cluster cluster_1208736_1208832.csv not found, skipping.
# Test file for cluster cluster_559824_559920.csv not found, skipping.
# Test file for cluster cluster_479184_479280.csv not found, skipping.
# Test file for cluster cluster_412848_412944.csv not found, skipping.
# Test file for cluster cluster_2472912_2473008.csv not found, skipping.
# Test file for cluster cluster_2754144_2754240.csv not found, skipping.
# Test file for cluster cluster_3595344_3595440.csv not found, skipping.
# Test file for cluster cluster_1261584_1261680.csv not found, skipping.
# Test file for cluster cluster_1938912_1939008.csv not found, skipping.
# Test file for cluster cluster_1428912_1429008.csv not found, skipping.
# Test file for cluster cluster_3757584_3757680.csv not found, skipping.
# Test file for cluster cluster_3308352_3308448.csv not found, skipping.
# Test file for cluster cluster_1946160_1946256.csv not found, skipping.
# Test file for cluster cluster_2507520_2507616.csv not found, skipping.
# Test file for cluster cluster_2572992_2573088.csv not found, skipping.
# Test file for cluster cluster_410448_410544.csv not found, skipping.
# Test file for cluster cluster_818016_818112.csv not found, skipping.
# Test file for cluster cluster_289872_289968.csv not found, skipping.
# Test file for cluster cluster_1205904_1206000.csv not found, skipping.
# Test file for cluster cluster_2423136_2423232.csv not found, skipping.
# Test file for cluster cluster_903168_903264.csv not found, skipping.
# Test file for cluster cluster_3292848_3292944.csv not found, skipping.
# Test file for cluster cluster_1583088_1583184.csv not found, skipping.
# Test file for cluster cluster_1256160_1256256.csv not found, skipping.
# Test file for cluster cluster_3416016_3416112.csv not found, skipping.
# Test file for cluster cluster_1607520_1607616.csv not found, skipping.
# Test file for cluster cluster_3099648_3099744.csv not found, skipping.
# Test file for cluster cluster_3725664_3725760.csv not found, skipping.
# Test file for cluster cluster_2828112_2828208.csv not found, skipping.
# Test file for cluster cluster_469776_469872.csv not found, skipping.
# Test file for cluster cluster_1234464_1234560.csv not found, skipping.
# Test file for cluster cluster_915408_915504.csv not found, skipping.
# Test file for cluster cluster_93408_93504.csv not found, skipping.
# Test file for cluster cluster_2859696_2859792.csv not found, skipping.
# Test file for cluster cluster_3298512_3298608.csv not found, skipping.
# Test file for cluster cluster_2443104_2443200.csv not found, skipping.
# Test file for cluster cluster_3007824_3007920.csv not found, skipping.
# Test file for cluster cluster_2247168_2247264.csv not found, skipping.
# Test file for cluster cluster_3241632_3241728.csv not found, skipping.
# Test file for cluster cluster_884496_884592.csv not found, skipping.
# Test file for cluster cluster_3737040_3737136.csv not found, skipping.
# Test file for cluster cluster_1331856_1331952.csv not found, skipping.
# Test file for cluster cluster_413664_413760.csv not found, skipping.
# Test file for cluster cluster_1207248_1207344.csv not found, skipping.
# Test file for cluster cluster_2602464_2602560.csv not found, skipping.
# Test file for cluster cluster_1076544_1076640.csv not found, skipping.
# Test file for cluster cluster_2253024_2253120.csv not found, skipping.
# Test file for cluster cluster_365232_365328.csv not found, skipping.
# Test file for cluster cluster_164784_164880.csv not found, skipping.
# Test file for cluster cluster_1704480_1704576.csv not found, skipping.
# Test file for cluster cluster_2716608_2716704.csv not found, skipping.
# Test file for cluster cluster_2091936_2092032.csv not found, skipping.
# Test file for cluster cluster_2710080_2710176.csv not found, skipping.
# Test file for cluster cluster_2178144_2178240.csv not found, skipping.
# Test file for cluster cluster_66720_66816.csv not found, skipping.
# Test file for cluster cluster_1492128_1492224.csv not found, skipping.
# Test file for cluster cluster_380304_380400.csv not found, skipping.
# Test file for cluster cluster_1435152_1435248.csv not found, skipping.
# Test file for cluster cluster_1797840_1797936.csv not found, skipping.
# Test file for cluster cluster_1946016_1946112.csv not found, skipping.
# Test file for cluster cluster_3601632_3601728.csv not found, skipping.
# Test file for cluster cluster_3579936_3580032.csv not found, skipping.
# Test file for cluster cluster_437088_437184.csv not found, skipping.
# Test file for cluster cluster_154560_154656.csv not found, skipping.
# Test file for cluster cluster_2786016_2786112.csv not found, skipping.
# Test file for cluster cluster_2515296_2515392.csv not found, skipping.
# Test file for cluster cluster_410592_410688.csv not found, skipping.
# Test file for cluster cluster_3365664_3365760.csv not found, skipping.
# Test file for cluster cluster_3610080_3610176.csv not found, skipping.
# Test file for cluster cluster_2587968_2588064.csv not found, skipping.
# Test file for cluster cluster_3191088_3191184.csv not found, skipping.
# Test file for cluster cluster_3509376_3509472.csv not found, skipping.
# Test file for cluster cluster_1141056_1141152.csv not found, skipping.
# Test file for cluster cluster_1550832_1550928.csv not found, skipping.
# Test file for cluster cluster_3389184_3389280.csv not found, skipping.
# Test file for cluster cluster_1768992_1769088.csv not found, skipping.
# Test file for cluster cluster_521760_521856.csv not found, skipping.
# Test file for cluster cluster_1191024_1191120.csv not found, skipping.
# Test file for cluster cluster_991920_992016.csv not found, skipping.
# Test file for cluster cluster_3541536_3541632.csv not found, skipping.
# Test file for cluster cluster_477984_478080.csv not found, skipping.
# Test file for cluster cluster_2377536_2377632.csv not found, skipping.
# Test file for cluster cluster_2107488_2107584.csv not found, skipping.
# Test file for cluster cluster_2812896_2812992.csv not found, skipping.
# Test file for cluster cluster_2943120_2943216.csv not found, skipping.
# Test file for cluster cluster_2887824_2887920.csv not found, skipping.
# Test file for cluster cluster_469632_469728.csv not found, skipping.
# Test file for cluster cluster_521088_521184.csv not found, skipping.
# Test file for cluster cluster_3526128_3526224.csv not found, skipping.
# Test file for cluster cluster_1260096_1260192.csv not found, skipping.
# Test file for cluster cluster_2020608_2020704.csv not found, skipping.
# Test file for cluster cluster_559680_559776.csv not found, skipping.
# Test file for cluster cluster_370080_370176.csv not found, skipping.
# Test file for cluster cluster_3083376_3083472.csv not found, skipping.
# Test file for cluster cluster_3515232_3515328.csv not found, skipping.
# Test file for cluster cluster_1067760_1067856.csv not found, skipping.
# Test file for cluster cluster_2247840_2247936.csv not found, skipping.
# Test file for cluster cluster_1968720_1968816.csv not found, skipping.
# Test file for cluster cluster_3137664_3137760.csv not found, skipping.
# Test file for cluster cluster_3416160_3416256.csv not found, skipping.
# Test file for cluster cluster_3703152_3703248.csv not found, skipping.
# Test file for cluster cluster_2516640_2516736.csv not found, skipping.
# Test file for cluster cluster_1316880_1316976.csv not found, skipping.
# Test file for cluster cluster_1123680_1123776.csv not found, skipping.
# Test file for cluster cluster_2859024_2859120.csv not found, skipping.
# Test file for cluster cluster_2424768_2424864.csv not found, skipping.
# Test file for cluster cluster_3757296_3757392.csv not found, skipping.
# Test file for cluster cluster_62016_62112.csv not found, skipping.
# Test file for cluster cluster_126528_126624.csv not found, skipping.
# Test file for cluster cluster_1281936_1282032.csv not found, skipping.
# Test file for cluster cluster_1925040_1925136.csv not found, skipping.
# Test file for cluster cluster_561024_561120.csv not found, skipping.
# Test file for cluster cluster_1036320_1036416.csv not found, skipping.
# Test file for cluster cluster_2605824_2605920.csv not found, skipping.
# Test file for cluster cluster_93264_93360.csv not found, skipping.
# Test file for cluster cluster_1738752_1738848.csv not found, skipping.
# Test file for cluster cluster_1647312_1647408.csv not found, skipping.
# Test file for cluster cluster_3611712_3611808.csv not found, skipping.
# Test file for cluster cluster_3374544_3374640.csv not found, skipping.
# Test file for cluster cluster_995328_995424.csv not found, skipping.
# Test file for cluster cluster_1916688_1916784.csv not found, skipping.
# Test file for cluster cluster_2530368_2530464.csv not found, skipping.
# Test file for cluster cluster_3382080_3382176.csv not found, skipping.
# Test file for cluster cluster_824592_824688.csv not found, skipping.
# Test file for cluster cluster_3364176_3364272.csv not found, skipping.
# Test file for cluster cluster_2478912_2479008.csv not found, skipping.
# Test file for cluster cluster_3003024_3003120.csv not found, skipping.
# Test file for cluster cluster_3436320_3436416.csv not found, skipping.
# Test file for cluster cluster_7584_7680.csv not found, skipping.
# Test file for cluster cluster_2215776_2215872.csv not found, skipping.
# Test file for cluster cluster_1157856_1157952.csv not found, skipping.
# Test file for cluster cluster_630480_630576.csv not found, skipping.
# Test file for cluster cluster_1462368_1462464.csv not found, skipping.
# Test file for cluster cluster_2051568_2051664.csv not found, skipping.
# Test file for cluster cluster_290016_290112.csv not found, skipping.
# Test file for cluster cluster_3514032_3514128.csv not found, skipping.
# Test file for cluster cluster_2635056_2635152.csv not found, skipping.
# Test file for cluster cluster_2684640_2684736.csv not found, skipping.
# Test file for cluster cluster_447264_447360.csv not found, skipping.
# Test file for cluster cluster_2205888_2205984.csv not found, skipping.
# Test file for cluster cluster_3273600_3273696.csv not found, skipping.
# Test file for cluster cluster_1315392_1315488.csv not found, skipping.
# Test file for cluster cluster_3046800_3046896.csv not found, skipping.
# Test file for cluster cluster_1104720_1104816.csv not found, skipping.
# Test file for cluster cluster_716976_717072.csv not found, skipping.
# Test file for cluster cluster_803760_803856.csv not found, skipping.
# Test file for cluster cluster_2654640_2654736.csv not found, skipping.
# Test file for cluster cluster_2769264_2769360.csv not found, skipping.
# Test file for cluster cluster_3277920_3278016.csv not found, skipping.
# Test file for cluster cluster_708096_708192.csv not found, skipping.
# Test file for cluster cluster_2631984_2632080.csv not found, skipping.
# Test file for cluster cluster_1362624_1362720.csv not found, skipping.
# Test file for cluster cluster_733392_733488.csv not found, skipping.
# Test file for cluster cluster_726240_726336.csv not found, skipping.
# Test file for cluster cluster_1395456_1395552.csv not found, skipping.
# Test file for cluster cluster_2851104_2851200.csv not found, skipping.
# Test file for cluster cluster_3343632_3343728.csv not found, skipping.
# Test file for cluster cluster_157776_157872.csv not found, skipping.
# Test file for cluster cluster_450816_450912.csv not found, skipping.
# Test file for cluster cluster_3243120_3243216.csv not found, skipping.
# Test file for cluster cluster_1624896_1624992.csv not found, skipping.
# Test file for cluster cluster_1980816_1980912.csv not found, skipping.
# Test file for cluster cluster_2190816_2190912.csv not found, skipping.
# Test file for cluster cluster_1159056_1159152.csv not found, skipping.
# Test file for cluster cluster_1246800_1246896.csv not found, skipping.
# Test file for cluster cluster_3233520_3233616.csv not found, skipping.
# Test file for cluster cluster_490368_490464.csv not found, skipping.
# Test file for cluster cluster_354768_354864.csv not found, skipping.
# Test file for cluster cluster_3198816_3198912.csv not found, skipping.
# Test file for cluster cluster_2693376_2693472.csv not found, skipping.
# Test file for cluster cluster_2689200_2689296.csv not found, skipping.
# Test file for cluster cluster_2608464_2608560.csv not found, skipping.
# Test file for cluster cluster_2257248_2257344.csv not found, skipping.
# Test file for cluster cluster_3495168_3495264.csv not found, skipping.
# Test file for cluster cluster_1989840_1989936.csv not found, skipping.
# Test file for cluster cluster_2077248_2077344.csv not found, skipping.
# Test file for cluster cluster_3685632_3685728.csv not found, skipping.
# Test file for cluster cluster_2626752_2626848.csv not found, skipping.
# Test file for cluster cluster_3857088_3857184.csv not found, skipping.
# Test file for cluster cluster_2468208_2468304.csv not found, skipping.
# Test file for cluster cluster_572784_572880.csv not found, skipping.
# Test file for cluster cluster_556320_556416.csv not found, skipping.
# Test file for cluster cluster_3086256_3086352.csv not found, skipping.
# Test file for cluster cluster_733152_733248.csv not found, skipping.
# Test file for cluster cluster_1954080_1954176.csv not found, skipping.
# Test file for cluster cluster_3320496_3320592.csv not found, skipping.
# Test file for cluster cluster_1354512_1354608.csv not found, skipping.
# Test file for cluster cluster_402912_403008.csv not found, skipping.
# Test file for cluster cluster_2762544_2762640.csv not found, skipping.
# Test file for cluster cluster_2404560_2404656.csv not found, skipping.
# Test file for cluster cluster_1776144_1776240.csv not found, skipping.
# Test file for cluster cluster_2102064_2102160.csv not found, skipping.
# Test file for cluster cluster_1607952_1608048.csv not found, skipping.
# Test file for cluster cluster_3151728_3151824.csv not found, skipping.
# Test file for cluster cluster_2175984_2176080.csv not found, skipping.
# Test file for cluster cluster_1332000_1332096.csv not found, skipping.
# Test file for cluster cluster_2325840_2325936.csv not found, skipping.
# Test file for cluster cluster_3041856_3041952.csv not found, skipping.
# Test file for cluster cluster_1615968_1616064.csv not found, skipping.
# Test file for cluster cluster_2022768_2022864.csv not found, skipping.
# Test file for cluster cluster_623280_623376.csv not found, skipping.
# Test file for cluster cluster_1214352_1214448.csv not found, skipping.
# Test file for cluster cluster_1870272_1870368.csv not found, skipping.
# Test file for cluster cluster_1594416_1594512.csv not found, skipping.
# Test file for cluster cluster_3270384_3270480.csv not found, skipping.
# Test file for cluster cluster_2429952_2430048.csv not found, skipping.
# Test file for cluster cluster_464784_464880.csv not found, skipping.
# Test file for cluster cluster_1462512_1462608.csv not found, skipping.
# Test file for cluster cluster_1607664_1607760.csv not found, skipping.
# Test file for cluster cluster_380160_380256.csv not found, skipping.
# Test file for cluster cluster_1512192_1512288.csv not found, skipping.
# Test file for cluster cluster_1105104_1105200.csv not found, skipping.
# Test file for cluster cluster_495600_495696.csv not found, skipping.
# Test file for cluster cluster_1527552_1527648.csv not found, skipping.
# Test file for cluster cluster_1851840_1851936.csv not found, skipping.
# Test file for cluster cluster_1728432_1728528.csv not found, skipping.
# Test file for cluster cluster_2546304_2546400.csv not found, skipping.
# Test file for cluster cluster_2191248_2191344.csv not found, skipping.
# Test file for cluster cluster_350832_350928.csv not found, skipping.
# Test file for cluster cluster_2334528_2334624.csv not found, skipping.
# Test file for cluster cluster_960240_960336.csv not found, skipping.
# Test file for cluster cluster_3442704_3442800.csv not found, skipping.
# Test file for cluster cluster_3660240_3660336.csv not found, skipping.
# Test file for cluster cluster_1332288_1332384.csv not found, skipping.
# Test file for cluster cluster_804048_804144.csv not found, skipping.
# Test file for cluster cluster_803376_803472.csv not found, skipping.
# Test file for cluster cluster_92976_93072.csv not found, skipping.
# Test file for cluster cluster_1771008_1771104.csv not found, skipping.
# Test file for cluster cluster_2064960_2065056.csv not found, skipping.
# Test file for cluster cluster_2853504_2853600.csv not found, skipping.
# Test file for cluster cluster_763632_763728.csv not found, skipping.
# Test file for cluster cluster_902784_902880.csv not found, skipping.
# Test file for cluster cluster_576816_576912.csv not found, skipping.
# Test file for cluster cluster_2026752_2026848.csv not found, skipping.
# Test file for cluster cluster_2831616_2831712.csv not found, skipping.
# Test file for cluster cluster_3257088_3257184.csv not found, skipping.
# Test file for cluster cluster_103344_103440.csv not found, skipping.
# Test file for cluster cluster_2565552_2565648.csv not found, skipping.
# Test file for cluster cluster_360864_360960.csv not found, skipping.
# Test file for cluster cluster_354528_354624.csv not found, skipping.
# Test file for cluster cluster_2935344_2935440.csv not found, skipping.
# Test file for cluster cluster_3190944_3191040.csv not found, skipping.
# Test file for cluster cluster_3565584_3565680.csv not found, skipping.
# Test file for cluster cluster_1057200_1057296.csv not found, skipping.
# Test file for cluster cluster_2931696_2931792.csv not found, skipping.
# Test file for cluster cluster_867552_867648.csv not found, skipping.
# Test file for cluster cluster_2515152_2515248.csv not found, skipping.
# Test file for cluster cluster_3252624_3252720.csv not found, skipping.
# Test file for cluster cluster_1028544_1028640.csv not found, skipping.
# Test file for cluster cluster_2168736_2168832.csv not found, skipping.
# Test file for cluster cluster_1214208_1214304.csv not found, skipping.
# Test file for cluster cluster_66576_66672.csv not found, skipping.
# Test file for cluster cluster_856416_856512.csv not found, skipping.
# Test file for cluster cluster_1682784_1682880.csv not found, skipping.
# Test file for cluster cluster_3093168_3093264.csv not found, skipping.
# Test file for cluster cluster_2960832_2960928.csv not found, skipping.
# Test file for cluster cluster_1856256_1856352.csv not found, skipping.
# Test file for cluster cluster_448416_448512.csv not found, skipping.
# Test file for cluster cluster_1688112_1688208.csv not found, skipping.
# Test file for cluster cluster_190944_191040.csv not found, skipping.
# Test file for cluster cluster_2417904_2418000.csv not found, skipping.
# Test file for cluster cluster_1545792_1545888.csv not found, skipping.
# Test file for cluster cluster_2256768_2256864.csv not found, skipping.
# Test file for cluster cluster_103200_103296.csv not found, skipping.
# Test file for cluster cluster_803520_803616.csv not found, skipping.
# Test file for cluster cluster_2556384_2556480.csv not found, skipping.
# Test file for cluster cluster_3330432_3330528.csv not found, skipping.
# Test file for cluster cluster_3820176_3820272.csv not found, skipping.
# Test file for cluster cluster_3517632_3517728.csv not found, skipping.
# Test file for cluster cluster_1048032_1048128.csv not found, skipping.
# Test file for cluster cluster_3219600_3219696.csv not found, skipping.
# Test file for cluster cluster_3070224_3070320.csv not found, skipping.
# Test file for cluster cluster_1293408_1293504.csv not found, skipping.
# Test file for cluster cluster_2521632_2521728.csv not found, skipping.
# Test file for cluster cluster_3332736_3332832.csv not found, skipping.
# Test file for cluster cluster_375600_375696.csv not found, skipping.
# Test file for cluster cluster_3039984_3040080.csv not found, skipping.
# Test file for cluster cluster_1390944_1391040.csv not found, skipping.
# Test file for cluster cluster_2944320_2944416.csv not found, skipping.
# Test file for cluster cluster_2181840_2181936.csv not found, skipping.
# Test file for cluster cluster_3352752_3352848.csv not found, skipping.
# Test file for cluster cluster_3277776_3277872.csv not found, skipping.
# Test file for cluster cluster_103488_103584.csv not found, skipping.
# Test file for cluster cluster_1435680_1435776.csv not found, skipping.
# Test file for cluster cluster_3480192_3480288.csv not found, skipping.
# Test file for cluster cluster_2108160_2108256.csv not found, skipping.
# Test file for cluster cluster_2588112_2588208.csv not found, skipping.
# Test file for cluster cluster_1904208_1904304.csv not found, skipping.
# Test file for cluster cluster_2654496_2654592.csv not found, skipping.
# Test file for cluster cluster_1981344_1981440.csv not found, skipping.
# Test file for cluster cluster_3181872_3181968.csv not found, skipping.
# Test file for cluster cluster_1628544_1628640.csv not found, skipping.
# Test file for cluster cluster_1279104_1279200.csv not found, skipping.
# Test file for cluster cluster_205440_205536.csv not found, skipping.
# Test file for cluster cluster_3317904_3318000.csv not found, skipping.
# Test file for cluster cluster_3108624_3108720.csv not found, skipping.
# Test file for cluster cluster_1593600_1593696.csv not found, skipping.
# Test file for cluster cluster_120672_120768.csv not found, skipping.
# Test file for cluster cluster_1659888_1659984.csv not found, skipping.
# Test file for cluster cluster_633168_633264.csv not found, skipping.
# Test file for cluster cluster_3521280_3521376.csv not found, skipping.
# Test file for cluster cluster_2793360_2793456.csv not found, skipping.
# Test file for cluster cluster_2140992_2141088.csv not found, skipping.
# Test file for cluster cluster_1157568_1157664.csv not found, skipping.
# Test file for cluster cluster_608352_608448.csv not found, skipping.
# Test file for cluster cluster_3192960_3193056.csv not found, skipping.
# Test file for cluster cluster_2590368_2590464.csv not found, skipping.
# Test file for cluster cluster_2036016_2036112.csv not found, skipping.
# Test file for cluster cluster_1041552_1041648.csv not found, skipping.
# Test file for cluster cluster_3554832_3554928.csv not found, skipping.
# Test file for cluster cluster_238272_238368.csv not found, skipping.
# Test file for cluster cluster_144528_144624.csv not found, skipping.
# Test file for cluster cluster_884736_884832.csv not found, skipping.
# Test file for cluster cluster_2156928_2157024.csv not found, skipping.
# Test file for cluster cluster_575616_575712.csv not found, skipping.
# Test file for cluster cluster_61872_61968.csv not found, skipping.
# Test file for cluster cluster_2345568_2345664.csv not found, skipping.
# Test file for cluster cluster_3073056_3073152.csv not found, skipping.
# Test file for cluster cluster_2082048_2082144.csv not found, skipping.
# Test file for cluster cluster_3359424_3359520.csv not found, skipping.
# Test file for cluster cluster_3479904_3480000.csv not found, skipping.
# Test file for cluster cluster_3153312_3153408.csv not found, skipping.
# Test file for cluster cluster_902496_902592.csv not found, skipping.
# Test file for cluster cluster_3195072_3195168.csv not found, skipping.
# Test file for cluster cluster_406560_406656.csv not found, skipping.
# Test file for cluster cluster_2175840_2175936.csv not found, skipping.
# Test file for cluster cluster_588048_588144.csv not found, skipping.
# Test file for cluster cluster_2491584_2491680.csv not found, skipping.
# Test file for cluster cluster_165600_165696.csv not found, skipping.
# Test file for cluster cluster_2021568_2021664.csv not found, skipping.
# Test file for cluster cluster_2390640_2390736.csv not found, skipping.
# Test file for cluster cluster_3430560_3430656.csv not found, skipping.
# Test file for cluster cluster_560352_560448.csv not found, skipping.
# Test file for cluster cluster_1784208_1784304.csv not found, skipping.
# Test file for cluster cluster_2689488_2689584.csv not found, skipping.
# Test file for cluster cluster_500208_500304.csv not found, skipping.
# Test file for cluster cluster_1154208_1154304.csv not found, skipping.
# Test file for cluster cluster_2768592_2768688.csv not found, skipping.
# Test file for cluster cluster_3813168_3813264.csv not found, skipping.
# Test file for cluster cluster_3745536_3745632.csv not found, skipping.
# Test file for cluster cluster_69408_69504.csv not found, skipping.
# Test file for cluster cluster_329952_330048.csv not found, skipping.
# Test file for cluster cluster_2422080_2422176.csv not found, skipping.
# Test file for cluster cluster_2546448_2546544.csv not found, skipping.
# Test file for cluster cluster_1585104_1585200.csv not found, skipping.
# Test file for cluster cluster_1913472_1913568.csv not found, skipping.
# Test file for cluster cluster_1324752_1324848.csv not found, skipping.
# Test file for cluster cluster_3189600_3189696.csv not found, skipping.
# Test file for cluster cluster_212160_212256.csv not found, skipping.
# Test file for cluster cluster_3712656_3712752.csv not found, skipping.
# Test file for cluster cluster_2592144_2592240.csv not found, skipping.
# Test file for cluster cluster_972096_972192.csv not found, skipping.
# Test file for cluster cluster_3332592_3332688.csv not found, skipping.
# Test file for cluster cluster_628128_628224.csv not found, skipping.
# Test file for cluster cluster_1273056_1273152.csv not found, skipping.
# Test file for cluster cluster_3562896_3562992.csv not found, skipping.
# Test file for cluster cluster_974112_974208.csv not found, skipping.
# Test file for cluster cluster_101712_101808.csv not found, skipping.
# Test file for cluster cluster_3724752_3724848.csv not found, skipping.
# Test file for cluster cluster_2228736_2228832.csv not found, skipping.
# Test file for cluster cluster_533904_534000.csv not found, skipping.
# Test file for cluster cluster_1508064_1508160.csv not found, skipping.
# Test file for cluster cluster_2129568_2129664.csv not found, skipping.
# Test file for cluster cluster_2484864_2484960.csv not found, skipping.
# Test file for cluster cluster_2164992_2165088.csv not found, skipping.
# Test file for cluster cluster_1621536_1621632.csv not found, skipping.
# Test file for cluster cluster_2423280_2423376.csv not found, skipping.
# Test file for cluster cluster_2173968_2174064.csv not found, skipping.
# Test file for cluster cluster_1989600_1989696.csv not found, skipping.
# Test file for cluster cluster_2734704_2734800.csv not found, skipping.
# Test file for cluster cluster_929424_929520.csv not found, skipping.
# Test file for cluster cluster_2981136_2981232.csv not found, skipping.
# Test file for cluster cluster_733824_733920.csv not found, skipping.
# Test file for cluster cluster_96480_96576.csv not found, skipping.
# Test file for cluster cluster_3365808_3365904.csv not found, skipping.
# Test file for cluster cluster_1308192_1308288.csv not found, skipping.
# Test file for cluster cluster_2594832_2594928.csv not found, skipping.
# Test file for cluster cluster_515328_515424.csv not found, skipping.
# Test file for cluster cluster_201792_201888.csv not found, skipping.
# Test file for cluster cluster_2418048_2418144.csv not found, skipping.
# Test file for cluster cluster_130656_130752.csv not found, skipping.
# Test file for cluster cluster_2680608_2680704.csv not found, skipping.
# Test file for cluster cluster_360576_360672.csv not found, skipping.
# Test file for cluster cluster_1177440_1177536.csv not found, skipping.
# Test file for cluster cluster_372768_372864.csv not found, skipping.
# Test file for cluster cluster_1246512_1246608.csv not found, skipping.
# Test file for cluster cluster_3734784_3734880.csv not found, skipping.
# Test file for cluster cluster_1083216_1083312.csv not found, skipping.
# Test file for cluster cluster_3158688_3158784.csv not found, skipping.
# Test file for cluster cluster_1062768_1062864.csv not found, skipping.
# Test file for cluster cluster_1497984_1498080.csv not found, skipping.
# Test file for cluster cluster_1249488_1249584.csv not found, skipping.
# Test file for cluster cluster_2215632_2215728.csv not found, skipping.
# Test file for cluster cluster_225648_225744.csv not found, skipping.
# Test file for cluster cluster_1080672_1080768.csv not found, skipping.
# Test file for cluster cluster_3175344_3175440.csv not found, skipping.
# Test file for cluster cluster_2081904_2082000.csv not found, skipping.
# Test file for cluster cluster_1134336_1134432.csv not found, skipping.
# Test file for cluster cluster_2583264_2583360.csv not found, skipping.
# Test file for cluster cluster_3837312_3837408.csv not found, skipping.
# Test file for cluster cluster_3488640_3488736.csv not found, skipping.
# Test file for cluster cluster_3280656_3280752.csv not found, skipping.
# Test file for cluster cluster_1500144_1500240.csv not found, skipping.
# Test file for cluster cluster_3857376_3857472.csv not found, skipping.
# Test file for cluster cluster_3263568_3263664.csv not found, skipping.
# Test file for cluster cluster_14400_14496.csv not found, skipping.
# Test file for cluster cluster_273456_273552.csv not found, skipping.
# Test file for cluster cluster_2409840_2409936.csv not found, skipping.
# Test file for cluster cluster_3722976_3723072.csv not found, skipping.
# Test file for cluster cluster_852144_852240.csv not found, skipping.
# Test file for cluster cluster_1337232_1337328.csv not found, skipping.
# Test file for cluster cluster_3852576_3852672.csv not found, skipping.
# Test file for cluster cluster_2363568_2363664.csv not found, skipping.
# Test file for cluster cluster_567408_567504.csv not found, skipping.
# Test file for cluster cluster_2773968_2774064.csv not found, skipping.
# Test file for cluster cluster_2107200_2107296.csv not found, skipping.
# Test file for cluster cluster_619536_619632.csv not found, skipping.
# Test file for cluster cluster_1868928_1869024.csv not found, skipping.
# Test file for cluster cluster_102000_102096.csv not found, skipping.
# Test file for cluster cluster_336528_336624.csv not found, skipping.
# Test file for cluster cluster_544176_544272.csv not found, skipping.
# Test file for cluster cluster_860976_861072.csv not found, skipping.
# Test file for cluster cluster_1925328_1925424.csv not found, skipping.
# Test file for cluster cluster_1012320_1012416.csv not found, skipping.
# Test file for cluster cluster_1219056_1219152.csv not found, skipping.
# Test file for cluster cluster_2481744_2481840.csv not found, skipping.
# Test file for cluster cluster_2832672_2832768.csv not found, skipping.
# Test file for cluster cluster_1884192_1884288.csv not found, skipping.
# Test file for cluster cluster_618864_618960.csv not found, skipping.
# Test file for cluster cluster_897936_898032.csv not found, skipping.
# Test file for cluster cluster_1361136_1361232.csv not found, skipping.
# Test file for cluster cluster_2417232_2417328.csv not found, skipping.
# Test file for cluster cluster_1086960_1087056.csv not found, skipping.
# Test file for cluster cluster_985776_985872.csv not found, skipping.
# Test file for cluster cluster_1503120_1503216.csv not found, skipping.
# Test file for cluster cluster_3737184_3737280.csv not found, skipping.
# Test file for cluster cluster_2562048_2562144.csv not found, skipping.
# Test file for cluster cluster_2395248_2395344.csv not found, skipping.
# Test file for cluster cluster_2129856_2129952.csv not found, skipping.
# Test file for cluster cluster_297984_298080.csv not found, skipping.
# Test file for cluster cluster_180384_180480.csv not found, skipping.
# Test file for cluster cluster_1067328_1067424.csv not found, skipping.
# Test file for cluster cluster_3729840_3729936.csv not found, skipping.
# Test file for cluster cluster_248592_248688.csv not found, skipping.
# Test file for cluster cluster_1035648_1035744.csv not found, skipping.
# Test file for cluster cluster_457968_458064.csv not found, skipping.
# Test file for cluster cluster_3069456_3069552.csv not found, skipping.
# Test file for cluster cluster_3007392_3007488.csv not found, skipping.
# Test file for cluster cluster_1161600_1161696.csv not found, skipping.
# Test file for cluster cluster_1868784_1868880.csv not found, skipping.
# Test file for cluster cluster_2994528_2994624.csv not found, skipping.
# Test file for cluster cluster_2510352_2510448.csv not found, skipping.
# Test file for cluster cluster_1357440_1357536.csv not found, skipping.
# Test file for cluster cluster_2948592_2948688.csv not found, skipping.
# Test file for cluster cluster_2222160_2222256.csv not found, skipping.
# Test file for cluster cluster_386880_386976.csv not found, skipping.
# Test file for cluster cluster_2540496_2540592.csv not found, skipping.
# Test file for cluster cluster_3627024_3627120.csv not found, skipping.
# Test file for cluster cluster_3445920_3446016.csv not found, skipping.
# Test file for cluster cluster_2508864_2508960.csv not found, skipping.
# Test file for cluster cluster_2464848_2464944.csv not found, skipping.
# Test file for cluster cluster_726672_726768.csv not found, skipping.
# Test file for cluster cluster_3757440_3757536.csv not found, skipping.
# Test file for cluster cluster_3685776_3685872.csv not found, skipping.
# Test file for cluster cluster_1596672_1596768.csv not found, skipping.
# Test file for cluster cluster_1352208_1352304.csv not found, skipping.
# Test file for cluster cluster_1562016_1562112.csv not found, skipping.
# Test file for cluster cluster_3264240_3264336.csv not found, skipping.
# Test file for cluster cluster_2733360_2733456.csv not found, skipping.
# Test file for cluster cluster_2847600_2847696.csv not found, skipping.
# Test file for cluster cluster_3617856_3617952.csv not found, skipping.
# Test file for cluster cluster_153456_153552.csv not found, skipping.
# Test file for cluster cluster_3459744_3459840.csv not found, skipping.
# Test file for cluster cluster_2345856_2345952.csv not found, skipping.
# Test file for cluster cluster_2073888_2073984.csv not found, skipping.
# Test file for cluster cluster_2930112_2930208.csv not found, skipping.
# Test file for cluster cluster_898080_898176.csv not found, skipping.
# ...
# Test file for cluster cluster_1838160_1838256.csv not found, skipping.
# Test file for cluster cluster_2703936_2704032.csv not found, skipping.
# Test file for cluster cluster_144960_145056.csv not found, skipping.
# Test file for cluster cluster_534048_534144.csv not found, skipping.
# Test file for cluster cluster_2291568_2291664.csv not found, skipping.
# Test file for cluster cluster_1401648_1401744.csv not found, skipping.
# Test file for cluster cluster_2840208_2840304.csv not found, skipping.
# Test file for cluster cluster_1628400_1628496.csv not found, skipping.
# Test file for cluster cluster_886080_886176.csv not found, skipping.
# Test file for cluster cluster_3845472_3845568.csv not found, skipping.
# Test file for cluster cluster_53280_53376.csv not found, skipping.
# Test file for cluster cluster_452448_452544.csv not found, skipping.
# Test file for cluster cluster_1018080_1018176.csv not found, skipping.
# Test file for cluster cluster_3320880_3320976.csv not found, skipping.
# Test file for cluster cluster_732048_732144.csv not found, skipping.
# Test file for cluster cluster_2102208_2102304.csv not found, skipping.
# Test file for cluster cluster_643776_643872.csv not found, skipping.
# Test file for cluster cluster_2456064_2456160.csv not found, skipping.
# Test file for cluster cluster_507312_507408.csv not found, skipping.
# Test file for cluster cluster_1131408_1131504.csv not found, skipping.
# Test file for cluster cluster_2597808_2597904.csv not found, skipping.
# Test file for cluster cluster_722592_722688.csv not found, skipping.
# Test file for cluster cluster_1672752_1672848.csv not found, skipping.
# Test file for cluster cluster_897408_897504.csv not found, skipping.
# Test file for cluster cluster_2215920_2216016.csv not found, skipping.
# Test file for cluster cluster_3857520_3857616.csv not found, skipping.
# Test file for cluster cluster_1492416_1492512.csv not found, skipping.
# Test file for cluster cluster_2625936_2626032.csv not found, skipping.
# Test file for cluster cluster_3809952_3810048.csv not found, skipping.
# Test file for cluster cluster_3723264_3723360.csv not found, skipping.
# Test file for cluster cluster_2528880_2528976.csv not found, skipping.
# Test file for cluster cluster_2838336_2838432.csv not found, skipping.
# Test file for cluster cluster_3505392_3505488.csv not found, skipping.
# Test file for cluster cluster_2363424_2363520.csv not found, skipping.
# Test file for cluster cluster_2715264_2715360.csv not found, skipping.
# Test file for cluster cluster_2898288_2898384.csv not found, skipping.
# Test file for cluster cluster_1037952_1038048.csv not found, skipping.
# Test file for cluster cluster_2550864_2550960.csv not found, skipping.
# Test file for cluster cluster_1628688_1628784.csv not found, skipping.
# Test file for cluster cluster_1271856_1271952.csv not found, skipping.
# Test file for cluster cluster_3828960_3829056.csv not found, skipping.
# Test file for cluster cluster_3405312_3405408.csv not found, skipping.
# Test file for cluster cluster_1265664_1265760.csv not found, skipping.
# Test file for cluster cluster_2782512_2782608.csv not found, skipping.
# Test file for cluster cluster_1479936_1480032.csv not found, skipping.
# Test file for cluster cluster_1849152_1849248.csv not found, skipping.
# Test file for cluster cluster_3263424_3263520.csv not found, skipping.
# Test file for cluster cluster_2445504_2445600.csv not found, skipping.
# Test file for cluster cluster_2582976_2583072.csv not found, skipping.
# Test file for cluster cluster_3526416_3526512.csv not found, skipping.
# Test file for cluster cluster_861120_861216.csv not found, skipping.
# Test file for cluster cluster_880320_880416.csv not found, skipping.
# Test file for cluster cluster_2782368_2782464.csv not found, skipping.
# Test file for cluster cluster_100128_100224.csv not found, skipping.
# Test file for cluster cluster_2832816_2832912.csv not found, skipping.
# Test file for cluster cluster_57456_57552.csv not found, skipping.
# Test file for cluster cluster_855600_855696.csv not found, skipping.
# Test file for cluster cluster_3473280_3473376.csv not found, skipping.
# Test file for cluster cluster_1419408_1419504.csv not found, skipping.
# Test file for cluster cluster_2241312_2241408.csv not found, skipping.
# Test file for cluster cluster_1636656_1636752.csv not found, skipping.
# Test file for cluster cluster_1543440_1543536.csv not found, skipping.
# Test file for cluster cluster_861264_861360.csv not found, skipping.
# Test file for cluster cluster_1390800_1390896.csv not found, skipping.
# Test file for cluster cluster_1012032_1012128.csv not found, skipping.
# Test file for cluster cluster_1865424_1865520.csv not found, skipping.
# Test file for cluster cluster_3368736_3368832.csv not found, skipping.
# Test file for cluster cluster_1512048_1512144.csv not found, skipping.
# Test file for cluster cluster_2889312_2889408.csv not found, skipping.
# Test file for cluster cluster_605808_605904.csv not found, skipping.
# Test file for cluster cluster_1673712_1673808.csv not found, skipping.
# Test file for cluster cluster_897648_897744.csv not found, skipping.
# Test file for cluster cluster_1923024_1923120.csv not found, skipping.
# Test file for cluster cluster_656976_657072.csv not found, skipping.
# Test file for cluster cluster_3273744_3273840.csv not found, skipping.
# Test file for cluster cluster_3729696_3729792.csv not found, skipping.
# Test file for cluster cluster_2447760_2447856.csv not found, skipping.
# Test file for cluster cluster_1208880_1208976.csv not found, skipping.
# Test file for cluster cluster_3201504_3201600.csv not found, skipping.
# Test file for cluster cluster_273168_273264.csv not found, skipping.
# Test file for cluster cluster_1848720_1848816.csv not found, skipping.
# Test file for cluster cluster_2182752_2182848.csv not found, skipping.
# Test file for cluster cluster_2573280_2573376.csv not found, skipping.
# Test file for cluster cluster_282864_282960.csv not found, skipping.
# Test file for cluster cluster_2653584_2653680.csv not found, skipping.
# Test file for cluster cluster_2252880_2252976.csv not found, skipping.
# Test file for cluster cluster_1108752_1108848.csv not found, skipping.
# Test file for cluster cluster_2608608_2608704.csv not found, skipping.
# Test file for cluster cluster_1590480_1590576.csv not found, skipping.
# Test file for cluster cluster_1733568_1733664.csv not found, skipping.
# Test file for cluster cluster_1865136_1865232.csv not found, skipping.
# Test file for cluster cluster_3270240_3270336.csv not found, skipping.
# Test file for cluster cluster_2522832_2522928.csv not found, skipping.
# Test file for cluster cluster_3190800_3190896.csv not found, skipping.
# Test file for cluster cluster_204480_204576.csv not found, skipping.
# Test file for cluster cluster_2926752_2926848.csv not found, skipping.
# Test file for cluster cluster_1223760_1223856.csv not found, skipping.
# Test file for cluster cluster_1420512_1420608.csv not found, skipping.
# Test file for cluster cluster_3269040_3269136.csv not found, skipping.
# Test file for cluster cluster_1098528_1098624.csv not found, skipping.
# Test file for cluster cluster_1051920_1052016.csv not found, skipping.
# Test file for cluster cluster_1711440_1711536.csv not found, skipping.
# Test file for cluster cluster_3203520_3203616.csv not found, skipping.
# Test file for cluster cluster_3573792_3573888.csv not found, skipping.
# Test file for cluster cluster_3787200_3787296.csv not found, skipping.
# Test file for cluster cluster_3627168_3627264.csv not found, skipping.
# Test file for cluster cluster_367632_367728.csv not found, skipping.
# Test file for cluster cluster_2536656_2536752.csv not found, skipping.
# Test file for cluster cluster_126144_126240.csv not found, skipping.
# Test file for cluster cluster_2786304_2786400.csv not found, skipping.
# Test file for cluster cluster_484896_484992.csv not found, skipping.
# Test file for cluster cluster_1295376_1295472.csv not found, skipping.
# Test file for cluster cluster_65232_65328.csv not found, skipping.
# Test file for cluster cluster_2670288_2670384.csv not found, skipping.
# Test file for cluster cluster_1946304_1946400.csv not found, skipping.
# Test file for cluster cluster_1839744_1839840.csv not found, skipping.
# Test file for cluster cluster_127056_127152.csv not found, skipping.
# Test file for cluster cluster_2941392_2941488.csv not found, skipping.
# Test file for cluster cluster_3079200_3079296.csv not found, skipping.
# Test file for cluster cluster_1159344_1159440.csv not found, skipping.
# Test file for cluster cluster_2642160_2642256.csv not found, skipping.
# Test file for cluster cluster_3480048_3480144.csv not found, skipping.
# Test file for cluster cluster_3153456_3153552.csv not found, skipping.
# Test file for cluster cluster_937584_937680.csv not found, skipping.
# Test file for cluster cluster_69120_69216.csv not found, skipping.
# Test file for cluster cluster_3779568_3779664.csv not found, skipping.
# Test file for cluster cluster_2136960_2137056.csv not found, skipping.
# Test file for cluster cluster_3541824_3541920.csv not found, skipping.
# Test file for cluster cluster_2583408_2583504.csv not found, skipping.
# Test file for cluster cluster_1672080_1672176.csv not found, skipping.
# Test file for cluster cluster_832272_832368.csv not found, skipping.
# Test file for cluster cluster_664320_664416.csv not found, skipping.
# Test file for cluster cluster_1083360_1083456.csv not found, skipping.
# Test file for cluster cluster_2041296_2041392.csv not found, skipping.
# Test file for cluster cluster_715248_715344.csv not found, skipping.
# Test file for cluster cluster_2023056_2023152.csv not found, skipping.
# Test file for cluster cluster_1085328_1085424.csv not found, skipping.
# Test file for cluster cluster_1204560_1204656.csv not found, skipping.
# Test file for cluster cluster_1242672_1242768.csv not found, skipping.
# Test file for cluster cluster_354384_354480.csv not found, skipping.
# Test file for cluster cluster_2510784_2510880.csv not found, skipping.
# Test file for cluster cluster_2716464_2716560.csv not found, skipping.
# Test file for cluster cluster_2058096_2058192.csv not found, skipping.
# Test file for cluster cluster_1405152_1405248.csv not found, skipping.
# Test file for cluster cluster_2768832_2768928.csv not found, skipping.
# Test file for cluster cluster_598224_598320.csv not found, skipping.
# Test file for cluster cluster_721776_721872.csv not found, skipping.
# Test file for cluster cluster_3632256_3632352.csv not found, skipping.
# Test file for cluster cluster_1513248_1513344.csv not found, skipping.
# Test file for cluster cluster_1491216_1491312.csv not found, skipping.
# Test file for cluster cluster_3678384_3678480.csv not found, skipping.
# Test file for cluster cluster_3047088_3047184.csv not found, skipping.
# Test file for cluster cluster_1840032_1840128.csv not found, skipping.
# Test file for cluster cluster_2347056_2347152.csv not found, skipping.
# Test file for cluster cluster_2563632_2563728.csv not found, skipping.
# Test file for cluster cluster_2635344_2635440.csv not found, skipping.
# Test file for cluster cluster_143328_143424.csv not found, skipping.
# Test file for cluster cluster_2125248_2125344.csv not found, skipping.
# Test file for cluster cluster_813216_813312.csv not found, skipping.
# Test file for cluster cluster_1786224_1786320.csv not found, skipping.
# Test file for cluster cluster_186480_186576.csv not found, skipping.
# Test file for cluster cluster_446592_446688.csv not found, skipping.
# Test file for cluster cluster_1833072_1833168.csv not found, skipping.
# Test file for cluster cluster_1511904_1512000.csv not found, skipping.
# Test file for cluster cluster_924816_924912.csv not found, skipping.
# Test file for cluster cluster_924000_924096.csv not found, skipping.
# Test file for cluster cluster_1002480_1002576.csv not found, skipping.
# Test file for cluster cluster_1368000_1368096.csv not found, skipping.
# Test file for cluster cluster_1341888_1341984.csv not found, skipping.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'top-1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 43
#      41 for metric in mem_metrics:
#      42     plt.figure(figsize=(3, 3))
# ---> 43     sns.regplot(data=df_merged, x=metric, y="top-1", scatter_kws={"s": 10, "alpha": 0.5}, line_kws={"color": "red"})
#      44     plt.xlabel(metric.title())
#      45     plt.ylabel("Top-1 Accuracy")
#
# File /usr/local/lib/python3.12/site-packages/seaborn/regression.py:763, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     752 def regplot(
#     753     data=None, *, x=None, y=None,
#     754     x_estimator=None, x_bins=None, x_ci="ci",
#    (...)    760     scatter_kws=None, line_kws=None, ax=None
#     761 ):
# --> 763     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     764                                  scatter, fit_reg, ci, n_boot, units, seed,
#     765                                  order, logistic, lowess, robust, logx,
#     766                                  x_partial, y_partial, truncate, dropna,
#     767                                  x_jitter, y_jitter, color, label)
#     769     if ax is None:
#     770         ax = plt.gca()
#
# File /usr/local/lib/python3.12/site-packages/seaborn/regression.py:107, in _RegressionPlotter.__init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     104     raise ValueError("Mutually exclusive regression options.")
#     106 # Extract the data vals from the arguments or passed dataframe
# --> 107 self.establish_variables(data, x=x, y=y, units=units,
#     108                          x_partial=x_partial, y_partial=y_partial)
#     110 # Drop null observations
#     111 if dropna:
#
# File /usr/local/lib/python3.12/site-packages/seaborn/regression.py:44, in _LinearPlotter.establish_variables(self, data, **kws)
#      42 for var, val in kws.items():
#      43     if isinstance(val, str):
# ---> 44         vector = data[val]
#      45     elif isinstance(val, list):
#      46         vector = np.asarray(val)
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'top-1'
